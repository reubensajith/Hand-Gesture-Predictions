# %%
import cv2
import numpy as np

# For Visualization in Jupyter
import ipywidgets as widgets
from matplotlib import pyplot as plt
from IPython.display import display
import os

# Get images and video into Jupyter from your webcam
from ipywebrtc import CameraStream, ImageRecorder, VideoRecorder

# %%
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd

# Sklearn
from sklearn.model_selection import train_test_split # Helps with organizing data for training
from sklearn.metrics import confusion_matrix # Helps present results as a confusion-matrix

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()


foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/102/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 0
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 345
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 105
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 107
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 371
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 388
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/159/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 389
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 502
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 262
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 303
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 538
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 580
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/294/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 642
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 777
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 475
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 482
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 736
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 733
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/441/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 840
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 957
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 642
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 709
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 976
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 949
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/564/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1036
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 1111
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 784
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 804
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 1086
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 1058
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/576/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1127
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 1296
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 885
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 902
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 1274
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 1163
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/609/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1227
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 1665
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 1187
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 1170
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 1657
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 1461
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/666/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1463
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 1839
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 1353
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 1377
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 1905
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 1612
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/711/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1653
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/open_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_palm/img_{}_00.png"

counter = 2002
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/fist_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_palm/img_{}_01.png"

counter = 1508
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/three_fingers_palm.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_palm/img_{}_02.png"

counter = 1504
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()


foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/open_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/open_dorsal/img_{}_03.png"

counter = 2071
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/fist_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/fist_dorsal/img_{}_04.png"

counter = 1804
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

foo = cv2.VideoCapture("Dataset Subsystem 1/videos/723/three_fingers_dorsal.webm")
ret, frame = foo.read()
path = "Dataset Subsystem 1/images/three_fingers_dorsal/img_{}_05.png"

counter = 1818
while ret:
    ret, frame = foo.read()
    if not ret:
        break

    location = path.format(counter)
    cv2.imwrite(path.format(counter), frame)
    counter += 1
foo.release()

# %%
imagepaths = []

# Go through all the files and subdirectories inside a folder and save path to images inside list
for root, dirs, files in os.walk(".", topdown=False): 
    for name in files:
        path = os.path.join(root, name)
        if path.endswith("png"): # We want only the images
            imagepaths.append(path)

print(len(imagepaths))
# Out:
# 11957

# %%
def plot_image(path):
    img = cv2.imread(path) # Reads the image into a numpy.array
    img_cvt = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Converts into the corret colorspace (RGB)
    print(img_cvt.shape) # Prints the shape of the image just to check
    plt.grid(False) # Without grid so we can see better
    plt.imshow(img_cvt) # Shows the image
    plt.xlabel("Width")
    plt.ylabel("Height")
    plt.title("Image " + path)

# %%
plot_image(imagepaths[2])
# Out:
# (480, 640)

# %%
X = [] # Image data
y = [] # Labels

# Loops through imagepaths to load images and labels into arrays
for path in imagepaths:
    img = cv2.imread(path) # Reads image and returns np.array
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Converts into the corret colorspace (GRAY)
    img = cv2.resize(img, (320, 120)) # Reduce image size so training can be faster
    X.append(img)
  
  # Processing label in image path
    category = path.split("/")[4]
#     print(category)
    label = int(category.split("_")[2][1]) # We need to convert 10_down to 00_down, or else it crashes
    y.append(label)

# Turn X and y into np.array to speed up train_test_split
X = np.array(X, dtype="uint8")
X = X.reshape(len(imagepaths), 120, 320, 1) # Needed to reshape so CNN knows it's different images
y = np.array(y)

print("Images loaded: ", len(X))
print("Labels loaded: ", len(y))

print(y[0], imagepaths[0]) # Debugging
# Out:
# Images loaded:  11957
# Labels loaded:  11957
# 1 ./Dataset Subsystem 1/images/fist_palm/img_1663_01.png

# %%
ts = 0.3 # Percentage of images that we want to use for testing. The rest is used for training.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ts, random_state=42)

# %%
# Import of keras model and hidden layers for our convolutional network
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten
# Out:
# Using TensorFlow backend.

# %%
# Construction of model
model = Sequential()
model.add(Conv2D(32, (5, 5), activation='relu', input_shape=(120, 320, 1))) 
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu')) 
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(6, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy']) # List of metrics to be evaluated by the model during training and testing.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 116, 316, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 58, 158, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 156, 64)       18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 78, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 76, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 38, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 31616)             0
# ...

# %%
model.fit(X_train, y_train, epochs=5, batch_size=64, verbose=2, validation_data=(X_test, y_test))
# Out:
# Train on 8369 samples, validate on 3588 samples
# Epoch 1/5
#  - 237s - loss: 4.6253 - accuracy: 0.8780 - val_loss: 0.0082 - val_accuracy: 0.9972
# Epoch 2/5
#  - 250s - loss: 0.0547 - accuracy: 0.9863 - val_loss: 0.0344 - val_accuracy: 0.9944
# Epoch 3/5
#  - 259s - loss: 0.0479 - accuracy: 0.9873 - val_loss: 0.0780 - val_accuracy: 0.9760
# Epoch 4/5
#  - 237s - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0015 - val_accuracy: 0.9997
# Epoch 5/5
#  - 236s - loss: 0.0107 - accuracy: 0.9975 - val_loss: 5.3302e-04 - val_accuracy: 0.9997

# %%
# Save entire model to a HDF5 file
model.save('handrecognition_model.h5')

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy: {:2.2f}%'.format(test_acc*100))
# Out:
# 3588/3588 [==============================] - 31s 9ms/step
# Test accuracy: 99.97%

# %%
predictions = model.predict(X_test)

# %%
predictions[0]
# Out:
# array([2.8335001e-09, 4.8841414e-10, 8.4931576e-12, 2.1610377e-10,
#        1.0000000e+00, 7.7867979e-10], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 4

# %%
len(predictions)
# Out:
# 3588

# %%
def validate_9_images(predictions_array, true_label_array, img_array):
  # Array for pretty printing and then figure size
  class_names = ["OP", "FP","TFP","OD","FD","TFD"] 
  plt.figure(figsize=(15,5))
  
  for i in range(1, 17):
    # Just assigning variables
    prediction = predictions_array[i+20]
    true_label = true_label_array[i+20]
    img = img_array[i+20]
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    
    # Plot in a good way
    plt.subplot(4,4,i)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(prediction) # Get index of the predicted label from prediction
    
    # Change color of title based on good prediction or not
    if predicted_label == true_label:
      color = 'blue'
    else:
      color = 'red'

    plt.xlabel("Predicted: {} {:2.0f}% (True: {})".format(class_names[predicted_label],
                                  100*np.max(prediction),
                                  class_names[true_label]),
                                  color=color)
  plt.show()

# %%
validate_9_images(predictions, y_test, X_test)

# %%
y_test
y_pred=[]
for i in range(0,3588):
    prediction = predictions[i]
    y_pred.append(np.argmax(prediction))

# %%
y_pred
# Out:
# [4,
#  5,
#  3,
#  5,
#  5,
#  5,
#  4,
#  0,
#  0,
#  2,
#  3,
#  5,
#  5,
#  0,
#  3,
#  4,
#  4,
#  4,
#  1,
#  4,
#  2,
#  5,
#  1,
#  5,
#  1,
#  1,
#  4,
#  5,
#  0,
#  3,
#  3,
#  5,
#  3,
#  1,
#  1,
#  1,
#  5,
#  3,
#  2,
#  1,
#  0,
#  4,
#  4,
#  1,
#  2,
#  4,
#  0,
#  5,
#  1,
#  4,
#  1,
#  0,
#  1,
#  0,
#  4,
#  5,
#  0,
#  5,
#  0,
#  0,
#  0,
#  0,
#  4,
#  1,
#  2,
#  4,
#  3,
#  4,
#  0,
#  0,
#  1,
#  0,
#  5,
#  2,
#  5,
#  3,
#  4,
#  1,
#  2,
#  2,
#  4,
#  4,
#  1,
#  3,
#  3,
#  5,
#  5,
#  2,
#  5,
#  5,
#  0,
#  4,
#  2,
#  3,
#  0,
#  3,
#  4,
#  0,
#  3,
#  2,
#  0,
#  0,
#  1,
#  5,
#  2,
#  3,
#  2,
#  3,
#  4,
#  2,
#  2,
#  0,
#  0,
#  5,
#  1,
#  3,
#  5,
#  5,
#  0,
#  2,
#  1,
#  4,
#  1,
#  3,
#  4,
#  0,
#  5,
#  4,
#  5,
#  1,
#  3,
#  4,
#  5,
#  2,
#  4,
#  3,
#  2,
#  1,
#  3,
#  0,
#  3,
#  4,
#  2,
#  4,
#  0,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2,
#  0,
#  4,
#  3,
#  3,
#  5,
#  3,
#  4,
#  2,
#  0,
#  0,
#  0,
#  5,
#  2,
#  1,
#  0,
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
plt.rcParams['figure.figsize'] = [10, 10]

labels = ["fist dorsal", "fist palm", "open dorsal", "open palm", "three fingers dorsal", "three fingers palm"]
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#                       precision    recall  f1-score   support
#
#          fist dorsal       1.00      1.00      1.00       648
#            fist palm       1.00      1.00      1.00       519
#          open dorsal       1.00      1.00      1.00       511
#            open palm       1.00      1.00      1.00       685
# three fingers dorsal       1.00      1.00      1.00       645
#   three fingers palm       1.00      1.00      1.00       580
#
#             accuracy                           1.00      3588
#            macro avg       1.00      1.00      1.00      3588
#         weighted avg       1.00      1.00      1.00      3588

# %%
camera = CameraStream(constraints=
                      {'facing_mode': 'user',
                       'audio': False,
                       'video': { 'width': 640, 'height': 480 }
                       })
camera
# Out:
# CameraStream(constraints={'facing_mode': 'user', 'audio': False, 'video': {'width': 640, 'height': 480}})

# %%
recorder = ImageRecorder(stream=camera)
recorder
# Out:
# ImageRecorder(image=Image(value=b''), stream=CameraStream(constraints={'facing_mode': 'user', 'audio': False, …

# %%
camera.close()

# %%
# extract the value from the ImageRecorder
snapshot = recorder.image.value
snapshot = np.frombuffer(snapshot, dtype=np.uint8)
snapshot = cv2.imdecode(snapshot, cv2.IMREAD_COLOR)

# %%
cv2.imwrite('snapshot.png', snapshot)
# Out:
# True

# %%
plot_image('snapshot.png')
# Out:
# (480, 640)

# %%
text_x=list()
img = cv2.imread('snapshot.png') # Reads image and returns np.array
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # Converts into the corret colorspace (GRAY)
img = cv2.resize(img, (320, 120)) # Reduce image size so training can be faster
test_x=img

# %%
test_x = np.array(test_x, dtype="uint8")
test_x = test_x.reshape(1, 120, 320, 1)

# %%
test_y=np.array(3)

# %%
prediction = model.predict(test_x)

# %%
prediction
# Out:
# array([[9.98413682e-01, 1.01965124e-04, 1.51512635e-04, 1.31540280e-03,
#         1.43258776e-05, 3.16604451e-06]], dtype=float32)

# %%
predicted_label = np.argmax(prediction)
predicted_label
# Out:
# 0
